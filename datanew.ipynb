# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
dataf = pd.read_csv('/home/ronit/Documents/try.csv')

cols = dataf.columns
col = cols[[0,1]]
df = dataf[col]
df


le_keywords = LabelEncoder()
le_label = LabelEncoder()


dataf['keyword_n'] = le_keywords.fit_transform(dataf['keywords'])
dataf['label_n'] = le_label.fit_transform(dataf['Label'])

dataf

inputs_n = dataf.drop(['keywords','Label','pdf'],axis='columns')

inputs_n.loc[:50]
# Out:
#     keyword_n  label_n
# 0           9        1
# 1           8        0
# 2          70        1
# 3          71        0
# 4          33        0
# 5          32        1
# 6           3        0
# 7           4        1
# 8           0        0
# 9          55        1
# 10         14        1
# 11         62        0
# 12         15        1
# 13         24        0
# 14         81        0
# 15         64        1
# 16         28        0
# 17         31        1
# 18         18        0
# 19         35        1
# 20         34        0
# 21         47        1
# 22         48        0
# 23         96        0
# 24         95        1
# 25         78        1
# 26         85        0
# 27         37        0
# 28         42        0
# 29         41        1
# 30         22        0
# 31         51        1
# 32         63        0
# 33         27        1
# 34         86        0
# 35         23        1
# 36         87        1
# 37         84        0
# 38         74        1
# ...
